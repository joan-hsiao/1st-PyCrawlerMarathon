# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11016761237","type":"CreateEvent","actor":{"id":22271652,"login":"howieshan","display_login":"howieshan","gravatar_id":"","url":"https://api.github.com/users/howieshan","avatar_url":"https://avatars.githubusercontent.com/u/22271652?"},"repo":{"id":226032527,"name":"howieshan/co.howie.leetcode","url":"https://api.github.com/repos/howieshan/co.howie.leetcode"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":"leetcode","pusher_type":"user"},"public":true,"created_at":"2019-12-05T06:31:27Z"},{"id":"11016761240","type":"PushEvent","actor":{"id":7303834,"login":"IgorNikolaev","display_login":"IgorNikolaev","gravatar_id":"","url":"https://api.github.com/users/IgorNikolaev","avatar_url":"https://avatars.githubusercontent.com/u/7303834?"},"repo":{"id":40655585,"name":"DarvinStudio/darvin-utils","url":"https://api.github.com/repos/DarvinStudio/darvin-utils"},"payload":{"push_id":4357923617,"size":1,"distinct_size":1,"ref":"refs/heads/7","head":"037b954b378e7121310fd93cce7450dfc99d5fbc","before":"aa997d9d6867d145ee2c994e392467179610d688","commits":[{"sha":"037b954b378e7121310fd93cce7450dfc99d5fbc","author":{"email":"igor.sv.n@gmail.com","name":"Igor Nikolaev"},"message":"Fix doc blocks.","distinct":true,"url":"https://api.github.com/repos/DarvinStudio/darvin-utils/commits/037b954b378e7121310fd93cce7450dfc99d5fbc"}]},"public":true,"created_at":"2019-12-05T06:31:27Z","org":{"id":13779251,"login":"DarvinStudio","gravatar_id":"","url":"https://api.github.com/orgs/DarvinStudio","avatar_url":"https://avatars.githubusercontent.com/u/13779251?"}},{"id":"11016761243","type":"ForkEvent","actor":{"id":31638637,"login":"kitter960324","display_login":"kitter960324","gravatar_id":"","url":"https://api.github.com/users/kitter960324","avatar_url":"https://avatars.githubusercontent.com/u/31638637?"},"repo":{"id":186361323,"name":"enilu/web-flash","url":"https://api.github.com/repos/enilu/web-flash"},"payload":{"forkee":{"id":226032533,"node_id":"MDEwOlJlcG9zaXRvcnkyMjYwMzI1MzM=","name":"web-flash","full_name":"kitter960324/web-flash","private":false,"owner":{"login":"kitter960324","id":31638637,"node_id":"MDQ6VXNlcjMxNjM4NjM3","avatar_url":"https://avatars3.githubusercontent.com/u/31638637?v=4","gravatar_id":"","url":"https://api.github.com/users/kitter960324","html_url":"https://github.com/kitter960324","followers_url":"https://api.github.com/users/kitter960324/followers","following_url":"https://api.github.com/users/kitter960324/following{/other_user}","gists_url":"https://api.github.com/users/kitter960324/gists{/gist_id}","starred_url":"https://api.github.com/users/kitter960324/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/kitter960324/subscriptions","organizations_url":"https://api.github.com/users/kitter960324/orgs","repos_url":"https://api.github.com/users/kitter960324/repos","events_url":"https://api.github.com/users/kitter960324/events{/privacy}","received_events_url":"https://api.github.com/users/kitter960324/received_events","type":"User","site_admin":false},"html_url":"https://github.com/kitter960324/web-flash","description":"WEB-FLASH --  Admin Framework and Mobile Website Based on Spring Boot and Vue.js","fork":true,"url":"https://api.github.com/repos/kitter960324/web-flash","forks_url":"https://api.github.com/repos/kitter960324/web-flash/forks","keys_url":"https://api.github.com/repos/kitter960324/web-flash/keys{/key_id}","collaborators_url":"https://api.github.com/repos/kitter960324/web-flash/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/kitter960324/web-flash/teams","hooks_url":"https://api.github.com/repos/kitter960324/web-flash/hooks","issue_events_url":"https://api.github.com/repos/kitter960324/web-flash/issues/events{/number}","events_url":"https://api.github.com/repos/kitter960324/web-flash/events","assignees_url":"https://api.github.com/repos/kitter960324/web-flash/assignees{/user}","branches_url":"https://api.github.com/repos/kitter9 ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11016761237',
#   'type': 'CreateEvent',
#   'actor': {'id': 22271652,
#    'login': 'howieshan',
#    'display_login': 'howieshan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/howieshan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22271652?'},
#   'repo': {'id': 226032527,
#    'name': 'howieshan/co.howie.leetcode',
#    'url': 'https://api.github.com/repos/howieshan/co.howie.leetcode'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'leetcode',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761240',
#   'type': 'PushEvent',
#   'actor': {'id': 7303834,
#    'login': 'IgorNikolaev',
#    'display_login': 'IgorNikolaev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IgorNikolaev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7303834?'},
#   'repo': {'id': 40655585,
#    'name': 'DarvinStudio/darvin-utils',
#    'url': 'https://api.github.com/repos/DarvinStudio/darvin-utils'},
#   'payload': {'push_id': 4357923617,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/7',
#    'head': '037b954b378e7121310fd93cce7450dfc99d5fbc',
#    'before': 'aa997d9d6867d145ee2c994e392467179610d688',
#    'commits': [{'sha': '037b954b378e7121310fd93cce7450dfc99d5fbc',
#      'author': {'email': 'igor.sv.n@gmail.com', 'name': 'Igor Nikolaev'},
#      'message': 'Fix doc blocks.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DarvinStudio/darvin-utils/commits/037b954b378e7121310fd93cce7450dfc99d5fbc'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z',
#   'org': {'id': 13779251,
#    'login': 'DarvinStudio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DarvinStudio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13779251?'}},
#  {'id': '11016761243',
#   'type': 'ForkEvent',
#   'actor': {'id': 31638637,
#    'login': 'kitter960324',
#    'display_login': 'kitter960324',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kitter960324',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31638637?'},
#   'repo': {'id': 186361323,
#    'name': 'enilu/web-flash',
#    'url': 'https://api.github.com/repos/enilu/web-flash'},
#   'payload': {'forkee': {'id': 226032533,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjYwMzI1MzM=',
#     'name': 'web-flash',
#     'full_name': 'kitter960324/web-flash',
#     'private': False,
#     'owner': {'login': 'kitter960324',
#      'id': 31638637,
#      'node_id': 'MDQ6VXNlcjMxNjM4NjM3',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/31638637?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kitter960324',
#      'html_url': 'https://github.com/kitter960324',
#      'followers_url': 'https://api.github.com/users/kitter960324/followers',
#      'following_url': 'https://api.github.com/users/kitter960324/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kitter960324/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kitter960324/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kitter960324/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kitter960324/orgs',
#      'repos_url': 'https://api.github.com/users/kitter960324/repos',
#      'events_url': 'https://api.github.com/users/kitter960324/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kitter960324/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/kitter960324/web-flash',
#     'description': 'WEB-FLASH --  Admin Framework and Mobile Website Based on Spring Boot and Vue.js',
#     'fork': True,
#     'url': 'https://api.github.com/repos/kitter960324/web-flash',
#     'forks_url': 'https://api.github.com/repos/kitter960324/web-flash/forks',
#     'keys_url': 'https://api.github.com/repos/kitter960324/web-flash/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/kitter960324/web-flash/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/kitter960324/web-flash/teams',
#     'hooks_url': 'https://api.github.com/repos/kitter960324/web-flash/hooks',
#     'issue_events_url': 'https://api.github.com/repos/kitter960324/web-flash/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/kitter960324/web-flash/events',
#     'assignees_url': 'https://api.github.com/repos/kitter960324/web-flash/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/kitter960324/web-flash/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/kitter960324/web-flash/tags',
#     'blobs_url': 'https://api.github.com/repos/kitter960324/web-flash/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/kitter960324/web-flash/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/kitter960324/web-flash/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/kitter960324/web-flash/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/kitter960324/web-flash/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/kitter960324/web-flash/languages',
#     'stargazers_url': 'https://api.github.com/repos/kitter960324/web-flash/stargazers',
#     'contributors_url': 'https://api.github.com/repos/kitter960324/web-flash/contributors',
#     'subscribers_url': 'https://api.github.com/repos/kitter960324/web-flash/subscribers',
#     'subscription_url': 'https://api.github.com/repos/kitter960324/web-flash/subscription',
#     'commits_url': 'https://api.github.com/repos/kitter960324/web-flash/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/kitter960324/web-flash/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/kitter960324/web-flash/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/kitter960324/web-flash/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/kitter960324/web-flash/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/kitter960324/web-flash/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/kitter960324/web-flash/merges',
#     'archive_url': 'https://api.github.com/repos/kitter960324/web-flash/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/kitter960324/web-flash/downloads',
#     'issues_url': 'https://api.github.com/repos/kitter960324/web-flash/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/kitter960324/web-flash/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/kitter960324/web-flash/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/kitter960324/web-flash/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/kitter960324/web-flash/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/kitter960324/web-flash/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/kitter960324/web-flash/deployments',
#     'created_at': '2019-12-05T06:31:27Z',
#     'updated_at': '2019-12-05T05:08:54Z',
#     'pushed_at': '2019-12-05T02:23:04Z',
#     'git_url': 'git://github.com/kitter960324/web-flash.git',
#     'ssh_url': 'git@github.com:kitter960324/web-flash.git',
#     'clone_url': 'https://github.com/kitter960324/web-flash.git',
#     'svn_url': 'https://github.com/kitter960324/web-flash',
#     'homepage': 'http://enilu.github.io/web-flash',
#     'size': 11113,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761241',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 162174233,
#    'name': 'SymbiFlow/symbiflow-docs',
#    'url': 'https://api.github.com/repos/SymbiFlow/symbiflow-docs'},
#   'payload': {'ref': 'dependabot/submodules/source/vtr-verilog-to-routing-136ecda',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Documentation for SymbiFlow',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z',
#   'org': {'id': 34549754,
#    'login': 'SymbiFlow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SymbiFlow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34549754?'}},
#  {'id': '11016761222',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46593810,
#    'name': 'Lombiq/Associativy-Frontend-Engines-Administration',
#    'url': 'https://api.github.com/repos/Lombiq/Associativy-Frontend-Engines-Administration'},
#   'payload': {'push_id': 4357923604,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.10',
#    'head': '6fa09986247d7f5841729b0b654cfa3393598ebd',
#    'before': '6fa09986247d7f5841729b0b654cfa3393598ebd',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11016761221',
#   'type': 'IssuesEvent',
#   'actor': {'id': 15977697,
#    'login': 'bcsoetta',
#    'display_login': 'bcsoetta',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bcsoetta',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15977697?'},
#   'repo': {'id': 209561296,
#    'name': 'bcsoetta/apishinta',
#    'url': 'https://api.github.com/repos/bcsoetta/apishinta'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/bcsoetta/apishinta/issues/20',
#     'repository_url': 'https://api.github.com/repos/bcsoetta/apishinta',
#     'labels_url': 'https://api.github.com/repos/bcsoetta/apishinta/issues/20/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/bcsoetta/apishinta/issues/20/comments',
#     'events_url': 'https://api.github.com/repos/bcsoetta/apishinta/issues/20/events',
#     'html_url': 'https://github.com/bcsoetta/apishinta/issues/20',
#     'id': 533153197,
#     'node_id': 'MDU6SXNzdWU1MzMxNTMxOTc=',
#     'number': 20,
#     'title': 'Penomoran dokumen',
#     'user': {'login': 'bcsoetta',
#      'id': 15977697,
#      'node_id': 'MDQ6VXNlcjE1OTc3Njk3',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/15977697?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bcsoetta',
#      'html_url': 'https://github.com/bcsoetta',
#      'followers_url': 'https://api.github.com/users/bcsoetta/followers',
#      'following_url': 'https://api.github.com/users/bcsoetta/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bcsoetta/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bcsoetta/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bcsoetta/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bcsoetta/orgs',
#      'repos_url': 'https://api.github.com/users/bcsoetta/repos',
#      'events_url': 'https://api.github.com/users/bcsoetta/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bcsoetta/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-05T06:31:27Z',
#     'updated_at': '2019-12-05T06:31:27Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'body': 'Sebaiknya dilakukan ketika melakukan penyimpanan dokumen untuk pertama kali. \r\nPenguncian dilakukan setelah dokumen penetapan diterbitkan.'}},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761215',
#   'type': 'PushEvent',
#   'actor': {'id': 15198872,
#    'login': 'OneJane',
#    'display_login': 'OneJane',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/OneJane',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15198872?'},
#   'repo': {'id': 197155395,
#    'name': 'OneJane/blog',
#    'url': 'https://api.github.com/repos/OneJane/blog'},
#   'payload': {'push_id': 4357923601,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9d956749de4f5cb047f350f280a60420b33216d2',
#    'before': 'a567e335f13bf1962c8a076fa20710882e851345',
#    'commits': [{'sha': '9d956749de4f5cb047f350f280a60420b33216d2',
#      'author': {'email': 'J1051103813@gmail.com', 'name': '王建'},
#      'message': '添加附件 : 小书匠/35a2e86581eab4665634593870fe5180.png',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OneJane/blog/commits/9d956749de4f5cb047f350f280a60420b33216d2'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761210',
#   'type': 'PushEvent',
#   'actor': {'id': 34637627,
#    'login': 'soob-forest',
#    'display_login': 'soob-forest',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/soob-forest',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34637627?'},
#   'repo': {'id': 218952410,
#    'name': 'connect-foundation/2019-16',
#    'url': 'https://api.github.com/repos/connect-foundation/2019-16'},
#   'payload': {'push_id': 4357923602,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/search_schema',
#    'head': '2463217a917b33e6c1c4f3170aa1d32fedffdb55',
#    'before': '68252bcb99077d78d5a8c421652a4170a46b7582',
#    'commits': [{'sha': '2463217a917b33e6c1c4f3170aa1d32fedffdb55',
#      'author': {'email': 'dltntnqo@naver.com', 'name': 'soob-forest'},
#      'message': 'test: test변경',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/connect-foundation/2019-16/commits/2463217a917b33e6c1c4f3170aa1d32fedffdb55'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z',
#   'org': {'id': 51152324,
#    'login': 'connect-foundation',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/connect-foundation',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51152324?'}},
#  {'id': '11016761212',
#   'type': 'ForkEvent',
#   'actor': {'id': 32123266,
#    'login': 'wicked00',
#    'display_login': 'wicked00',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wicked00',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32123266?'},
#   'repo': {'id': 696954,
#    'name': 'nvie/vimrc',
#    'url': 'https://api.github.com/repos/nvie/vimrc'},
#   'payload': {'forkee': {'id': 226032530,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjYwMzI1MzA=',
#     'name': 'vimrc',
#     'full_name': 'wicked00/vimrc',
#     'private': False,
#     'owner': {'login': 'wicked00',
#      'id': 32123266,
#      'node_id': 'MDQ6VXNlcjMyMTIzMjY2',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/32123266?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wicked00',
#      'html_url': 'https://github.com/wicked00',
#      'followers_url': 'https://api.github.com/users/wicked00/followers',
#      'following_url': 'https://api.github.com/users/wicked00/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wicked00/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wicked00/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wicked00/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wicked00/orgs',
#      'repos_url': 'https://api.github.com/users/wicked00/repos',
#      'events_url': 'https://api.github.com/users/wicked00/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wicked00/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/wicked00/vimrc',
#     'description': 'My personal Vim configuration, with a lot of love put into it.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/wicked00/vimrc',
#     'forks_url': 'https://api.github.com/repos/wicked00/vimrc/forks',
#     'keys_url': 'https://api.github.com/repos/wicked00/vimrc/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/wicked00/vimrc/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/wicked00/vimrc/teams',
#     'hooks_url': 'https://api.github.com/repos/wicked00/vimrc/hooks',
#     'issue_events_url': 'https://api.github.com/repos/wicked00/vimrc/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/wicked00/vimrc/events',
#     'assignees_url': 'https://api.github.com/repos/wicked00/vimrc/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/wicked00/vimrc/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/wicked00/vimrc/tags',
#     'blobs_url': 'https://api.github.com/repos/wicked00/vimrc/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/wicked00/vimrc/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/wicked00/vimrc/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/wicked00/vimrc/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/wicked00/vimrc/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/wicked00/vimrc/languages',
#     'stargazers_url': 'https://api.github.com/repos/wicked00/vimrc/stargazers',
#     'contributors_url': 'https://api.github.com/repos/wicked00/vimrc/contributors',
#     'subscribers_url': 'https://api.github.com/repos/wicked00/vimrc/subscribers',
#     'subscription_url': 'https://api.github.com/repos/wicked00/vimrc/subscription',
#     'commits_url': 'https://api.github.com/repos/wicked00/vimrc/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/wicked00/vimrc/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/wicked00/vimrc/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/wicked00/vimrc/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/wicked00/vimrc/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/wicked00/vimrc/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/wicked00/vimrc/merges',
#     'archive_url': 'https://api.github.com/repos/wicked00/vimrc/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/wicked00/vimrc/downloads',
#     'issues_url': 'https://api.github.com/repos/wicked00/vimrc/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/wicked00/vimrc/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/wicked00/vimrc/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/wicked00/vimrc/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/wicked00/vimrc/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/wicked00/vimrc/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/wicked00/vimrc/deployments',
#     'created_at': '2019-12-05T06:31:26Z',
#     'updated_at': '2019-12-03T20:02:53Z',
#     'pushed_at': '2019-12-03T20:02:51Z',
#     'git_url': 'git://github.com/wicked00/vimrc.git',
#     'ssh_url': 'git@github.com:wicked00/vimrc.git',
#     'clone_url': 'https://github.com/wicked00/vimrc.git',
#     'svn_url': 'https://github.com/wicked00/vimrc',
#     'homepage': '',
#     'size': 2049,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761189',
#   'type': 'PushEvent',
#   'actor': {'id': 58103019,
#    'login': 'NehaP92',
#    'display_login': 'NehaP92',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NehaP92',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58103019?'},
#   'repo': {'id': 226028104,
#    'name': 'NehaP92/map-filter-lab-python-data-science-intro-000',
#    'url': 'https://api.github.com/repos/NehaP92/map-filter-lab-python-data-science-intro-000'},
#   'payload': {'push_id': 4357923591,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': 'ae23d6467240860031d568c14639d98d9e8aebb8',
#    'before': '364b785e9ebb95107a9bf483cdacfd987b0a859c',
#    'commits': [{'sha': 'ae23d6467240860031d568c14639d98d9e8aebb8',
#      'author': {'email': 'nehabpp92@gmail.com', 'name': 'Neha Patel'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NehaP92/map-filter-lab-python-data-science-intro-000/commits/ae23d6467240860031d568c14639d98d9e8aebb8'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761204',
#   'type': 'PushEvent',
#   'actor': {'id': 25272594,
#    'login': 'pratikunterwegs',
#    'display_login': 'pratikunterwegs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pratikunterwegs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25272594?'},
#   'repo': {'id': 127874609,
#    'name': 'pratikunterwegs/redknotMoveWaddensea',
#    'url': 'https://api.github.com/repos/pratikunterwegs/redknotMoveWaddensea'},
#   'payload': {'push_id': 4357923596,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ebd6c9d82206bc3ed634c8f17b7d436ad5cf9abc',
#    'before': '169cdd87cfa97d4d72c7d300430454ebd5ed5220',
#    'commits': [{'sha': 'ebd6c9d82206bc3ed634c8f17b7d436ad5cf9abc',
#      'author': {'email': 'pratikgupte16@gmail.com', 'name': 'Pratik Gupte'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pratikunterwegs/redknotMoveWaddensea/commits/ebd6c9d82206bc3ed634c8f17b7d436ad5cf9abc'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761196',
#   'type': 'PushEvent',
#   'actor': {'id': 663849,
#    'login': 'hoanganhduc',
#    'display_login': 'hoanganhduc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hoanganhduc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/663849?'},
#   'repo': {'id': 217627544,
#    'name': 'hoanganhduc/hoanganhduc.github.io',
#    'url': 'https://api.github.com/repos/hoanganhduc/hoanganhduc.github.io'},
#   'payload': {'push_id': 4357923594,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/source',
#    'head': '3eadddd2e47299fd40cae9eefd13a3162899cf64',
#    'before': '2dda307c1f9046ee53e37425bd3a91acd3bea3fe',
#    'commits': [{'sha': '3eadddd2e47299fd40cae9eefd13a3162899cf64',
#      'author': {'email': 'anhduc.hoang1990@gmail.com', 'name': 'Duc A. Hoang'},
#      'message': 'Source Files @ 2019-12-05  15:31:11 JST [skip travis]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hoanganhduc/hoanganhduc.github.io/commits/3eadddd2e47299fd40cae9eefd13a3162899cf64'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761206',
#   'type': 'CreateEvent',
#   'actor': {'id': 58544629,
#    'login': 'nocab90',
#    'display_login': 'nocab90',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nocab90',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58544629?'},
#   'repo': {'id': 226031551,
#    'name': 'nocab90/TheRepo.github.io',
#    'url': 'https://api.github.com/repos/nocab90/TheRepo.github.io'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761191',
#   'type': 'WatchEvent',
#   'actor': {'id': 27499319,
#    'login': 'LuoBinRobin',
#    'display_login': 'LuoBinRobin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LuoBinRobin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27499319?'},
#   'repo': {'id': 60159997,
#    'name': 'YiiGuxing/TranslationPlugin',
#    'url': 'https://api.github.com/repos/YiiGuxing/TranslationPlugin'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761199',
#   'type': 'ForkEvent',
#   'actor': {'id': 1918027,
#    'login': 'froi',
#    'display_login': 'froi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/froi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1918027?'},
#   'repo': {'id': 212681810,
#    'name': 'actions/.github',
#    'url': 'https://api.github.com/repos/actions/.github'},
#   'payload': {'forkee': {'id': 226032529,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjYwMzI1Mjk=',
#     'name': '.github',
#     'full_name': 'froi/.github',
#     'private': False,
#     'owner': {'login': 'froi',
#      'id': 1918027,
#      'node_id': 'MDQ6VXNlcjE5MTgwMjc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/1918027?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/froi',
#      'html_url': 'https://github.com/froi',
#      'followers_url': 'https://api.github.com/users/froi/followers',
#      'following_url': 'https://api.github.com/users/froi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/froi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/froi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/froi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/froi/orgs',
#      'repos_url': 'https://api.github.com/users/froi/repos',
#      'events_url': 'https://api.github.com/users/froi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/froi/received_events',
#      'type': 'User',
#      'site_admin': True},
#     'html_url': 'https://github.com/froi/.github',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/froi/.github',
#     'forks_url': 'https://api.github.com/repos/froi/.github/forks',
#     'keys_url': 'https://api.github.com/repos/froi/.github/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/froi/.github/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/froi/.github/teams',
#     'hooks_url': 'https://api.github.com/repos/froi/.github/hooks',
#     'issue_events_url': 'https://api.github.com/repos/froi/.github/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/froi/.github/events',
#     'assignees_url': 'https://api.github.com/repos/froi/.github/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/froi/.github/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/froi/.github/tags',
#     'blobs_url': 'https://api.github.com/repos/froi/.github/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/froi/.github/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/froi/.github/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/froi/.github/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/froi/.github/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/froi/.github/languages',
#     'stargazers_url': 'https://api.github.com/repos/froi/.github/stargazers',
#     'contributors_url': 'https://api.github.com/repos/froi/.github/contributors',
#     'subscribers_url': 'https://api.github.com/repos/froi/.github/subscribers',
#     'subscription_url': 'https://api.github.com/repos/froi/.github/subscription',
#     'commits_url': 'https://api.github.com/repos/froi/.github/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/froi/.github/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/froi/.github/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/froi/.github/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/froi/.github/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/froi/.github/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/froi/.github/merges',
#     'archive_url': 'https://api.github.com/repos/froi/.github/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/froi/.github/downloads',
#     'issues_url': 'https://api.github.com/repos/froi/.github/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/froi/.github/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/froi/.github/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/froi/.github/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/froi/.github/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/froi/.github/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/froi/.github/deployments',
#     'created_at': '2019-12-05T06:31:25Z',
#     'updated_at': '2019-12-02T23:10:20Z',
#     'pushed_at': '2019-11-16T14:58:08Z',
#     'git_url': 'git://github.com/froi/.github.git',
#     'ssh_url': 'git@github.com:froi/.github.git',
#     'clone_url': 'https://github.com/froi/.github.git',
#     'svn_url': 'https://github.com/froi/.github',
#     'homepage': None,
#     'size': 12,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z',
#   'org': {'id': 44036562,
#    'login': 'actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/actions',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44036562?'}},
#  {'id': '11016761182',
#   'type': 'IssuesEvent',
#   'actor': {'id': 24931281,
#    'login': 'david-ziffity',
#    'display_login': 'david-ziffity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/david-ziffity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24931281?'},
#   'repo': {'id': 17608126,
#    'name': 'magento/devdocs',
#    'url': 'https://api.github.com/repos/magento/devdocs'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/magento/devdocs/issues/6125',
#     'repository_url': 'https://api.github.com/repos/magento/devdocs',
#     'labels_url': 'https://api.github.com/repos/magento/devdocs/issues/6125/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/magento/devdocs/issues/6125/comments',
#     'events_url': 'https://api.github.com/repos/magento/devdocs/issues/6125/events',
#     'html_url': 'https://github.com/magento/devdocs/issues/6125',
#     'id': 533153195,
#     'node_id': 'MDU6SXNzdWU1MzMxNTMxOTU=',
#     'number': 6125,
#     'title': 'Feedback on page: /guides/v2.3/frontend-dev-guide/css-topics/css-critical-path.html',
#     'user': {'login': 'david-ziffity',
#      'id': 24931281,
#      'node_id': 'MDQ6VXNlcjI0OTMxMjgx',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/24931281?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/david-ziffity',
#      'html_url': 'https://github.com/david-ziffity',
#      'followers_url': 'https://api.github.com/users/david-ziffity/followers',
#      'following_url': 'https://api.github.com/users/david-ziffity/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/david-ziffity/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/david-ziffity/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/david-ziffity/subscriptions',
#      'organizations_url': 'https://api.github.com/users/david-ziffity/orgs',
#      'repos_url': 'https://api.github.com/users/david-ziffity/repos',
#      'events_url': 'https://api.github.com/users/david-ziffity/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/david-ziffity/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-05T06:31:26Z',
#     'updated_at': '2019-12-05T06:31:26Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "# General issue\r\nExternal link icon not displaying \r\n## Description:\r\nExternal link svg icon implemented as background which is not displaying in the browser chrome Version 75.0.3770.142 (Official Build) (64-bit)  in upuntu\r\n<!-- (REQUIRED) What is the issue/current behavior? -->\r\nExternal link icon not displaying in chrome Version 75.0.3770.142 (Official Build) (64-bit) upuntu\r\n## Possible solutions:\r\n\r\n<!-- (OPTIONAL) What would a solution for this issue look like? -->\r\n\r\n## Additional information:\r\n\r\n<!-- (OPTIONAL) What other information can you provide about this issue? -->\r\n\r\n<!--\r\nThank you for taking the time to report this issue!\r\nGitHub Issues should only be created for problems/topics related to this project's codebase.\r\n\r\nBefore submitting this issue, please make sure you are complying with our Code of Conduct:\r\nhttps://github.com/magento/devdocs/blob/develop/.github/CODE_OF_CONDUCT.md\r\n\r\nIssues that do not comply with our Code of Conduct or do not contain enough information may be closed at the maintainers' discretion.\r\n\r\nFeel free to remove this section before creating this issue.\r\n-->\r\n"}},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z',
#   'org': {'id': 168457,
#    'login': 'magento',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/magento',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/168457?'}},
#  {'id': '11016761184',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 17303641,
#    'name': 'chef/chef-dk',
#    'url': 'https://api.github.com/repos/chef/chef-dk'},
#   'payload': {'action': 'opened',
#    'number': 2515,
#    'pull_request': {'url': 'https://api.github.com/repos/chef/chef-dk/pulls/2515',
#     'id': 349278110,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ5Mjc4MTEw',
#     'html_url': 'https://github.com/chef/chef-dk/pull/2515',
#     'diff_url': 'https://github.com/chef/chef-dk/pull/2515.diff',
#     'patch_url': 'https://github.com/chef/chef-dk/pull/2515.patch',
#     'issue_url': 'https://api.github.com/repos/chef/chef-dk/issues/2515',
#     'number': 2515,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump aws-partitions from 1.250.0 to 1.251.0 in /omnibus',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [aws-partitions](https://github.com/aws/aws-sdk-ruby) from 1.250.0 to 1.251.0.\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [aws-partitions\'s changelog](https://github.com/aws/aws-sdk-ruby/blob/master/gems/aws-partitions/CHANGELOG.md).*\n\n> 1.251.0 (2019-12-05)\n> ------------------\n> \n> * Feature - Added support for enumerating regions for `Aws::KinesisVideoSignalingChannels`.\n</details>\n<details>\n<summary>Commits</summary>\n\n- See full diff in [compare view](https://github.com/aws/aws-sdk-ruby/commits)\n</details>\n<br />\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=aws-partitions&package-manager=bundler&previous-version=1.250.0&new-version=1.251.0)](https://dependabot.com/compatibility-score.html?dependency-name=aws-partitions&package-manager=bundler&previous-version=1.250.0&new-version=1.251.0)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n- `@dependabot badge me` will comment on this PR with code to add a "Dependabot enabled" badge to your readme\n\nAdditionally, you can set the following in your Dependabot [dashboard](https://app.dependabot.com):\n- Update frequency (including time of day and day of week)\n- Pull request limits (per update run and/or open at any time)\n- Out-of-range updates (receive only lockfile updates, if desired)\n- Security updates (receive only security updates, if desired)\n\n\n\n</details>',
#     'created_at': '2019-12-05T06:31:26Z',
#     'updated_at': '2019-12-05T06:31:26Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [{'name': 'Chef Workstation Owners',
#       'id': 3204247,
#       'node_id': 'MDQ6VGVhbTMyMDQyNDc=',
#       'slug': 'chef-workstation-owners',
#       'description': 'Owners for the Chef Workstation project',
#       'privacy': 'closed',
#       'url': 'https://api.github.com/teams/3204247',
#       'html_url': 'https://github.com/orgs/chef/teams/chef-workstation-owners',
#       'members_url': 'https://api.github.com/teams/3204247/members{/member}',
#       'repositories_url': 'https://api.github.com/teams/3204247/repos',
#       'permission': 'pull'},
#      {'name': 'Chef Workstation Approvers',
#       'id': 3204249,
#       'node_id': 'MDQ6VGVhbTMyMDQyNDk=',
#       'slug': 'chef-workstation-approvers',
#       'description': 'Approvers for the Chef Workstation project',
#       'privacy': 'closed',
#       'url': 'https://api.github.com/teams/3204249',
#       'html_url': 'https://github.com/orgs/chef/teams/chef-workstation-approvers',
#       'members_url': 'https://api.github.com/teams/3204249/members{/member}',
#       'repositories_url': 'https://api.github.com/teams/3204249/repos',
#       'permission': 'pull'}],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/chef/chef-dk/pulls/2515/commits',
#     'review_comments_url': 'https://api.github.com/repos/chef/chef-dk/pulls/2515/comments',
#     'review_comment_url': 'https://api.github.com/repos/chef/chef-dk/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/chef/chef-dk/issues/2515/comments',
#     'statuses_url': 'https://api.github.com/repos/chef/chef-dk/statuses/be0530e540a3241455a4d588913dc9110d547c93',
#     'head': {'label': 'chef:dependabot/bundler/omnibus/chefdk-3/aws-partitions-1.251.0',
#      'ref': 'dependabot/bundler/omnibus/chefdk-3/aws-partitions-1.251.0',
#      'sha': 'be0530e540a3241455a4d588913dc9110d547c93',
#      'user': {'login': 'chef',
#       'id': 29740,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI5NzQw',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/29740?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/chef',
#       'html_url': 'https://github.com/chef',
#       'followers_url': 'https://api.github.com/users/chef/followers',
#       'following_url': 'https://api.github.com/users/chef/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/chef/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/chef/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/chef/subscriptions',
#       'organizations_url': 'https://api.github.com/users/chef/orgs',
#       'repos_url': 'https://api.github.com/users/chef/repos',
#       'events_url': 'https://api.github.com/users/chef/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/chef/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 17303641,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzMwMzY0MQ==',
#       'name': 'chef-dk',
#       'full_name': 'chef/chef-dk',
#       'private': False,
#       'owner': {'login': 'chef',
#        'id': 29740,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI5NzQw',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/29740?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/chef',
#        'html_url': 'https://github.com/chef',
#        'followers_url': 'https://api.github.com/users/chef/followers',
#        'following_url': 'https://api.github.com/users/chef/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/chef/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/chef/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/chef/subscriptions',
#        'organizations_url': 'https://api.github.com/users/chef/orgs',
#        'repos_url': 'https://api.github.com/users/chef/repos',
#        'events_url': 'https://api.github.com/users/chef/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/chef/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/chef/chef-dk',
#       'description': 'A streamlined development and deployment workflow for Chef platform.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/chef/chef-dk',
#       'forks_url': 'https://api.github.com/repos/chef/chef-dk/forks',
#       'keys_url': 'https://api.github.com/repos/chef/chef-dk/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/chef/chef-dk/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/chef/chef-dk/teams',
#       'hooks_url': 'https://api.github.com/repos/chef/chef-dk/hooks',
#       'issue_events_url': 'https://api.github.com/repos/chef/chef-dk/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/chef/chef-dk/events',
#       'assignees_url': 'https://api.github.com/repos/chef/chef-dk/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/chef/chef-dk/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/chef/chef-dk/tags',
#       'blobs_url': 'https://api.github.com/repos/chef/chef-dk/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/chef/chef-dk/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/chef/chef-dk/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/chef/chef-dk/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/chef/chef-dk/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/chef/chef-dk/languages',
#       'stargazers_url': 'https://api.github.com/repos/chef/chef-dk/stargazers',
#       'contributors_url': 'https://api.github.com/repos/chef/chef-dk/contributors',
#       'subscribers_url': 'https://api.github.com/repos/chef/chef-dk/subscribers',
#       'subscription_url': 'https://api.github.com/repos/chef/chef-dk/subscription',
#       'commits_url': 'https://api.github.com/repos/chef/chef-dk/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/chef/chef-dk/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/chef/chef-dk/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/chef/chef-dk/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/chef/chef-dk/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/chef/chef-dk/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/chef/chef-dk/merges',
#       'archive_url': 'https://api.github.com/repos/chef/chef-dk/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/chef/chef-dk/downloads',
#       'issues_url': 'https://api.github.com/repos/chef/chef-dk/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/chef/chef-dk/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/chef/chef-dk/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/chef/chef-dk/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/chef/chef-dk/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/chef/chef-dk/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/chef/chef-dk/deployments',
#       'created_at': '2014-02-28T23:59:39Z',
#       'updated_at': '2019-12-05T06:28:06Z',
#       'pushed_at': '2019-12-05T06:31:25Z',
#       'git_url': 'git://github.com/chef/chef-dk.git',
#       'ssh_url': 'git@github.com:chef/chef-dk.git',
#       'clone_url': 'https://github.com/chef/chef-dk.git',
#       'svn_url': 'https://github.com/chef/chef-dk',
#       'homepage': None,
#       'size': 10032,
#       'stargazers_count': 392,
#       'watchers_count': 392,
#       'language': 'Ruby',
# ...
#      'url': 'https://api.github.com/repos/pequet/public-logs/commits/1bcecb5d7fa618e6b33664c6a6476ecca187c7ca'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761178',
#   'type': 'DeleteEvent',
#   'actor': {'id': 22772637,
#    'login': 'juzerzarif',
#    'display_login': 'juzerzarif',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juzerzarif',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22772637?'},
#   'repo': {'id': 220884853,
#    'name': 'juzerzarif/terra-wdio-helper',
#    'url': 'https://api.github.com/repos/juzerzarif/terra-wdio-helper'},
#   'payload': {'ref': 'feat/snapshot-webview',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761173',
#   'type': 'PushEvent',
#   'actor': {'id': 11382765,
#    'login': 'raymond92928',
#    'display_login': 'raymond92928',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/raymond92928',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11382765?'},
#   'repo': {'id': 226029174,
#    'name': 'raymond92928/Application-math',
#    'url': 'https://api.github.com/repos/raymond92928/Application-math'},
#   'payload': {'push_id': 4357923587,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1083fc014ea61e3fcc893a5d0d27563d05064b84',
#    'before': '6be4058129ec9d68c0962f9d9c31910930aafe29',
#    'commits': [{'sha': '1083fc014ea61e3fcc893a5d0d27563d05064b84',
#      'author': {'email': 'xis767@yahoo.com.hk', 'name': 'raymond92928'},
#      'message': 'Delete question1.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/raymond92928/Application-math/commits/1083fc014ea61e3fcc893a5d0d27563d05064b84'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:27Z'},
#  {'id': '11016761162',
#   'type': 'PushEvent',
#   'actor': {'id': 9419009,
#    'login': 'jij000',
#    'display_login': 'jij000',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jij000',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9419009?'},
#   'repo': {'id': 220914999,
#    'name': 'jij000/gitbook-Knowledge-Base',
#    'url': 'https://api.github.com/repos/jij000/gitbook-Knowledge-Base'},
#   'payload': {'push_id': 4357923583,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f646bf563244f2d037c6b7c50f3b430321d68512',
#    'before': 'd78d25f561bca4c2c55cf506f5ae9e5fd5a63031',
#    'commits': [{'sha': 'f646bf563244f2d037c6b7c50f3b430321d68512',
#      'author': {'email': 'jij000@gmail.com', 'name': 'Yanjun Jiang'},
#      'message': 'GitBook: [master] one page modified',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jij000/gitbook-Knowledge-Base/commits/f646bf563244f2d037c6b7c50f3b430321d68512'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:26Z'},
#  {'id': '11016761163',
#   'type': 'PushEvent',
#   'actor': {'id': 58393240,
#    'login': 'VangalaHimakethanReddy',
#    'display_login': 'VangalaHimakethanReddy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VangalaHimakethanReddy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58393240?'},
#   'repo': {'id': 225299642,
#    'name': 'VangalaHimakethanReddy/CRT-Program',
#    'url': 'https://api.github.com/repos/VangalaHimakethanReddy/CRT-Program'},
#   'payload': {'push_id': 4357923584,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a86e55439a5effc247d47881c145db3bdd7ad74b',
#    'before': 'ddb8ac4d85bc99e11ee22fc90c195d777a40bc5a',
#    'commits': [{'sha': 'a86e55439a5effc247d47881c145db3bdd7ad74b',
#      'author': {'email': '58393240+VangalaHimakethanReddy@users.noreply.github.com',
#       'name': 'VangalaHimakethanReddy'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/VangalaHimakethanReddy/CRT-Program/commits/a86e55439a5effc247d47881c145db3bdd7ad74b'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:26Z'},
#  {'id': '11016761153',
#   'type': 'PushEvent',
#   'actor': {'id': 18218145,
#    'login': 'AutorestCI',
#    'display_login': 'AutorestCI',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AutorestCI',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18218145?'},
#   'repo': {'id': 194751519,
#    'name': 'AzureSDKAutomation/azure-sdk-for-go',
#    'url': 'https://api.github.com/repos/AzureSDKAutomation/azure-sdk-for-go'},
#   'payload': {'push_id': 4357923565,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e56ec3f142bfbc83f619f7e7eaf72abf03a3ef17',
#    'before': '0820c0553d6c410603056869f7b0e52d61ce5bee',
#    'commits': [{'sha': 'e56ec3f142bfbc83f619f7e7eaf72abf03a3ef17',
#      'author': {'email': 'dapzhang@microsoft.com', 'name': 'Arcturus'},
#      'message': 'v37.0.0 (#6449)\n\n* Generated from 027c5530dd98ce87a84ba78c3e3cf8d2451d0c13 (#5569)\r\n\r\nFixed the formatting\r\n\r\n* [AutoPR eventhub/resource-manager] Eventhub: added NetworkRuleSets list API (#5627)\r\n\r\n* Generated from 46cb463f5dbcd442661875e4eb9d963af3bd1225\r\n\r\nadded NetworkRuleSets list API\r\n\r\n* Generated from c09ca0cf8b2a8d98ee64b897e1858f4be8a67f95\r\n\r\nadded x-ms-pageable and formating\r\n\r\n* Generated from 8bc2a7edfeebb1a6bb30abbbb03d08bf1f8a8dbc\r\n\r\nupdate\r\n\r\n* Generated from 111d1bc1666fe89cebb960135cf2f5336bbcb35a (#5615)\r\n\r\nRemoved rogue file\r\n\r\n* [AutoPR machinelearningservices/resource-manager] [NEED DESIGN REVIEW, DO NOT MERGE] Adding workspace level quota management APIs in version 2019-05-01 (#5641)\r\n\r\n* Generated from f5ddfe85225c2d4f86f7de8e99760b95d1dea6bf\r\n\r\nMerge branch \'master\' into leizhao/workspaceQuotaManagementInVersion2019-05-01\r\n\r\n* Generated from c89caf92470c4c334883662fd98e6bd07881807d\r\n\r\nmigrate quota management from 2019-05-01 to 2019-06-01, no content changes\r\n\r\n* [AutoPR storagecache/resource-manager] Dev storagecache microsoft.storagecache 2019 06 01 preview (#5623)\r\n\r\n* Generated from 570b6f73542c34f1eb0ab0a85e44b4d929ff55b6\r\n\r\nFix output folder path for GO SDK and fix typo in Tag\r\n\r\n* Generated from 908e3cd2e18a38be0711e03035c7acdc7ab6d1f2\r\n\r\nFix version in the path of output folder for GO SDK\r\n\r\n* Generated from 10811b8f33c5e36350b618955cdd8edc9dd67c11 (#5673)\r\n\r\nFix bad package name for storagecache in go sdk\r\n\r\n* Fix bad package name\r\n\r\n* Fix profile and fmt\r\n\r\n* Generated from 54eb3260d53865005eb6ccfdc9843e7ab10d9da5 (#5551)\r\n\r\nadding maintenanceConfiguration list and resourceId for updates\r\n\r\n* Generated from be2943341d08ab5972e4d2385b1860d34ee61f59 (#5675)\r\n\r\nFix bad namespace in service maintenance\r\n\r\n* Fix wrong namespace\r\n\r\n* Fix profile and fmt\r\n\r\n* Generated from 3bcf3602288f763a70a2f3cb10100406e0e53257 (#5672)\r\n\r\nAddressed misspelled word and mode error\r\n\r\n* Generated from 5e1bb35d5c3314d8f4fead76c3d69a2522be026b (#5651)\r\n\r\nUpdate review comments\r\n\r\n* [AutoPR datafactory/resource-manager] support Express Custom Setup (#5536)\r\n\r\n* Generated from 696212c605edef333cba0f0e86d42ba344f4fc42\r\n\r\naddress the comments\r\n\r\n* Generated from 4de64a2262df8e2e971620c95f7c3a2ba91d49d9\r\n\r\naddress comments\r\n\r\n* Generated from fc0bdde313743dbbed8e8c506dd9e07107d04142\r\n\r\nMerge branch \'master\' into ivan/support-express-custom-setup-for-manged-ir\r\n\r\n* Generated from fc0bdde313743dbbed8e8c506dd9e07107d04142\r\n\r\nMerge branch \'master\' into ivan/support-express-custom-setup-for-manged-ir\r\n\r\n* [AutoPR datafactory/resource-manager] [Data Factory]Add ORC Dataset/Copy Source/Copy Sink (#5611)\r\n\r\n* Generated from 864a2b3827b7237d7cb60d77069b693dcbaf7001\r\n\r\n[DataFactory]Add support for ORC dataset\r\n\r\n* Generated from 864a2b3827b7237d7cb60d77069b693dcbaf7001\r\n\r\n[DataFactory]Add support for ORC dataset\r\n\r\n* Fix CI failure and conflict\r\n\r\n* [AutoPR] compute/resource-manager (#5688)\r\n\r\n* [AutoPR compute/resource-manager] removing non-ascii character (#5325)\r\n\r\n* Generated from 090b727225320af61034c7278c3ccf51dcbef8a2\r\n\r\nremoving non-ascii character\r\n\r\n* Generated from 56ccb1151588cff87c1c92eee0e6c56e42c7f2f4\r\n\r\ncorrected the description\r\n\r\n* [AutoPR compute/resource-manager] Add terminate profile and scheduled events profile to Microsoft.Compute (#5310)\r\n\r\n* Generated from 9bb1d5b7f21a0e03e97ce3817554307244d45422\r\n\r\nCorrect definition format\r\n\r\n* Generated from 49bbc9237680dc7963f9d24f7cde1d05e8f14260\r\n\r\nMerge branch \'master\' into dev/szimmer/AddTerminateProfile\r\n\r\n* [AutoPR compute/resource-manager] Add missing Gallery Application API in 2019-07-01 version (#5354)\r\n\r\n* Generated from 01293ebd64fa96d11d30d9b0ef1391cbe8e62443\r\n\r\nAdd missing Gallery App ...
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AzureSDKAutomation/azure-sdk-for-go/commits/e56ec3f142bfbc83f619f7e7eaf72abf03a3ef17'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:26Z',
#   'org': {'id': 50844873,
#    'login': 'AzureSDKAutomation',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/AzureSDKAutomation',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50844873?'}},
#  {'id': '11016761154',
#   'type': 'PushEvent',
#   'actor': {'id': 42590291,
#    'login': 'aaqibism',
#    'display_login': 'aaqibism',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aaqibism',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42590291?'},
#   'repo': {'id': 224102829,
#    'name': 'aaqibism/FareChecker',
#    'url': 'https://api.github.com/repos/aaqibism/FareChecker'},
#   'payload': {'push_id': 4357923576,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '76be5d02622c7057850b412571f9a08427347e24',
#    'before': '90d7571c8cfe863901f91de5d07f71678ee834a3',
#    'commits': [{'sha': '76be5d02622c7057850b412571f9a08427347e24',
#      'author': {'email': 'aaqibism@usc.edu', 'name': 'Aaqib Ismail'},
#      'message': 'SAD FACE',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aaqibism/FareChecker/commits/76be5d02622c7057850b412571f9a08427347e24'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:26Z'},
#  {'id': '11016761158',
#   'type': 'PushEvent',
#   'actor': {'id': 42283162,
#    'login': 'aws-aemilia',
#    'display_login': 'aws-aemilia',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aws-aemilia',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42283162?'},
#   'repo': {'id': 157814411,
#    'name': 'aws-aemilia/CanaryTestOnly-DoNotTouch-beta-us-west-2',
#    'url': 'https://api.github.com/repos/aws-aemilia/CanaryTestOnly-DoNotTouch-beta-us-west-2'},
#   'payload': {'push_id': 4357923581,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/branch1',
#    'head': '3bb0af12c459f219ffa5d0f84b5a3e0a33fcd708',
#    'before': '3f40d22c5a48de501f64f866e533c3d5078d6704',
#    'commits': [{'sha': '3bb0af12c459f219ffa5d0f84b5a3e0a33fcd708',
#      'author': {'email': 'aemilia@amazon.com', 'name': 'AemiliaCanary'},
#      'message': 'This is a test.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aws-aemilia/CanaryTestOnly-DoNotTouch-beta-us-west-2/commits/3bb0af12c459f219ffa5d0f84b5a3e0a33fcd708'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:26Z'},
#  {'id': '11016761165',
#   'type': 'CreateEvent',
#   'actor': {'id': 22718886,
#    'login': 'hileix',
#    'display_login': 'hileix',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hileix',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22718886?'},
#   'repo': {'id': 209700330,
#    'name': 'hifeteam/cat-ui',
#    'url': 'https://api.github.com/repos/hifeteam/cat-ui'},
#   'payload': {'ref': '2.6.0',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': '喜马拉雅国际版前端 ui 组件库  https://hifeteam.github.io/cat-ui/',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T06:31:26Z',
#   'org': {'id': 41612803,
#    'login': 'hifeteam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hifeteam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41612803?'}},
#  {'id': '11016761149',
#   'type': 'WatchEvent',
#   'actor': {'id': 27985996,
#    'login': 'zhangqi-blog',
#    'display_login': 'zhangqi-blog',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhangqi-blog',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27985996?'},
#   'repo': {'id': 873328,
#    'name': 'getsentry/sentry',
#    'url': 'https://api.github.com/repos/getsentry/sentry'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-05T06:31:26Z',
#   'org': {'id': 1396951,
#    'login': 'getsentry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/getsentry',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1396951?'}},
#  {'id': '11016761148',
#   'type': 'CreateEvent',
#   'actor': {'id': 1770056,
#    'login': 'charrondev',
#    'display_login': 'charrondev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/charrondev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1770056?'},
#   'repo': {'id': 232390,
#    'name': 'vanilla/vanilla',
#    'url': 'https://api.github.com/repos/vanilla/vanilla'},
#   'payload': {'ref': 'refactor/theme-packages',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Vanilla is a powerfully simple discussion forum you can easily customize to make as unique as your community.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T06:31:26Z',
#   'org': {'id': 7443552,
#    'login': 'vanilla',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/vanilla',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7443552?'}},
#  {'id': '11016761147',
#   'type': 'PushEvent',
#   'actor': {'id': 23307155,
#    'login': 'RAKWireless',
#    'display_login': 'RAKWireless',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RAKWireless',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23307155?'},
#   'repo': {'id': 194613653,
#    'name': 'RAKWireless/rak_common_for_gateway',
#    'url': 'https://api.github.com/repos/RAKWireless/rak_common_for_gateway'},
#   'payload': {'push_id': 4357923568,
#    'size': 5,
#    'distinct_size': 0,
#    'ref': 'refs/heads/dev',
#    'head': 'd970d4f8fedeae56ebdfd2fde24d8006ade74d9f',
#    'before': 'a4e43440d1f5c98b5b47551e1b2698f6edd3bfca',
#    'commits': [{'sha': '61aebbba0cf2a6c549a38dc98039b771ab575c56',
#      'author': {'email': 'fomi@rakwireless.com', 'name': 'RAKwireless'},
#      'message': 'Update README.md',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/RAKWireless/rak_common_for_gateway/commits/61aebbba0cf2a6c549a38dc98039b771ab575c56'},
#     {'sha': '3751ec20c01a0c0f181b5a4418708f76ad76cdef',
#      'author': {'email': 'fomi@rakwireless.com', 'name': 'RAKwireless'},
#      'message': 'Update README.md',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/RAKWireless/rak_common_for_gateway/commits/3751ec20c01a0c0f181b5a4418708f76ad76cdef'},
#     {'sha': 'f882297e76d2003848479813b32738556a40cd47',
#      'author': {'email': 'fomi@rakwireless.com', 'name': 'RAKwireless'},
#      'message': 'Update README.md',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/RAKWireless/rak_common_for_gateway/commits/f882297e76d2003848479813b32738556a40cd47'},
#     {'sha': 'f38cfbf65a7c43c6354f28b730c5c6a65350cc38',
#      'author': {'email': 'fomi@rakwireless.com', 'name': 'RAKwireless'},
#      'message': 'Update gateway-config',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/RAKWireless/rak_common_for_gateway/commits/f38cfbf65a7c43c6354f28b730c5c6a65350cc38'},
#     {'sha': 'd970d4f8fedeae56ebdfd2fde24d8006ade74d9f',
#      'author': {'email': 'fomi@rakwireless.com', 'name': 'RAKwireless'},
#      'message': 'Update README.md',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/RAKWireless/rak_common_for_gateway/commits/d970d4f8fedeae56ebdfd2fde24d8006ade74d9f'}]},
#   'public': True,
#   'created_at': '2019-12-05T06:31:26Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
